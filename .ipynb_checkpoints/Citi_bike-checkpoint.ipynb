# %%
import pandas as pd
import os

# %%
data_07 = pd.read_csv('D:\\GT-VIRT-DATA-PT-03-2022-U-LOL\CitiBike\Resources\JC-202007-citibike-tripdata.csv')

# %%
data_07.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1          1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2           786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3          1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4          2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
#
#    start station id          start station name  start station latitude  \
# 0              3694              Jackson Square               40.711130
# 1              3791  Hoboken Ave at Monmouth St               40.735208
# 2              3792  Columbus Dr at Exchange Pl               40.716870
# 3              3677                Glenwood Ave               40.727551
# 4              3191                    Union St               40.718211
#
#    start station longitude  end station id       end station name  \
# ...

# %%
data_08=pd.read_csv('D:\GT-VIRT-DATA-PT-03-2022-U-LOL\CitiBike\Resources\JC-202008-citibike-tripdata.csv')

# %%
data_08.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1           236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2           384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3          1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4          5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717732
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3185          City Hall               40.717732
# 4              3185          City Hall               40.717732
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3185        City Hall
# ...

# %%
data_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43267 entries, 0 to 43266
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             43267 non-null  int64
#  1   starttime                43267 non-null  object
#  2   stoptime                 43267 non-null  object
#  3   start station id         43267 non-null  int64
#  4   start station name       43267 non-null  object
#  5   start station latitude   43267 non-null  float64
#  6   start station longitude  43267 non-null  float64
#  7   end station id           43267 non-null  int64
#  8   end station name         43267 non-null  object
#  9   end station latitude     43267 non-null  float64
#  10  end station longitude    43267 non-null  float64
#  11  bikeid                   43267 non-null  int64
#  12  usertype                 43267 non-null  object
#  13  birth year               43267 non-null  int64
# ...

# %%
data_09=pd.read_csv('D:\GT-VIRT-DATA-PT-03-2022-U-LOL\CitiBike\Resources\JC-202009-citibike-tripdata.csv')

# %%
data_09.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           222  2020-09-01 00:15:58.6470  2020-09-01 00:19:40.8750
# 1           193  2020-09-01 00:49:00.7370  2020-09-01 00:52:14.3640
# 2           273  2020-09-01 00:51:44.5870  2020-09-01 00:56:17.7160
# 3          1419  2020-09-01 00:52:48.3160  2020-09-01 01:16:28.0490
# 4           254  2020-09-01 00:56:16.7170  2020-09-01 01:00:31.0870
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3640     Journal Square               40.733670
# 2              3191           Union St               40.718211
# 3              3203      Hamilton Park               40.727596
# 4              3194    McGinley Square               40.725340
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3276  Marin Light Rail
# ...

# %%
data_09.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53833 entries, 0 to 53832
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             53833 non-null  int64
#  1   starttime                53833 non-null  object
#  2   stoptime                 53833 non-null  object
#  3   start station id         53833 non-null  int64
#  4   start station name       53833 non-null  object
#  5   start station latitude   53833 non-null  float64
#  6   start station longitude  53833 non-null  float64
#  7   end station id           53833 non-null  int64
#  8   end station name         53833 non-null  object
#  9   end station latitude     53833 non-null  float64
#  10  end station longitude    53833 non-null  float64
#  11  bikeid                   53833 non-null  int64
#  12  usertype                 53833 non-null  object
#  13  birth year               53833 non-null  int64
# ...

# %%
data_10=pd.read_csv('D:\GT-VIRT-DATA-PT-03-2022-U-LOL\CitiBike\Resources\JC-202010-citibike-tripdata.csv')

# %%
data_10.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           156  2020-10-01 00:02:40.2600  2020-10-01 00:05:17.0140
# 1           143  2020-10-01 00:02:53.5020  2020-10-01 00:05:16.9650
# 2           305  2020-10-01 00:04:31.3160  2020-10-01 00:09:36.3840
# 3          1097  2020-10-01 00:05:18.3680  2020-10-01 00:23:36.1240
# 4           277  2020-10-01 00:09:17.5990  2020-10-01 00:13:55.5150
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3273       Manila & 1st               40.721651
# 3              3199       Newport Pkwy               40.728745
# 4              3199       Newport Pkwy               40.728745
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3270      Jersey & 6th St
# ...

# %%
data_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30086 entries, 0 to 30085
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             30086 non-null  int64
#  1   starttime                30086 non-null  object
#  2   stoptime                 30086 non-null  object
#  3   start station id         30086 non-null  int64
#  4   start station name       30086 non-null  object
#  5   start station latitude   30086 non-null  float64
#  6   start station longitude  30086 non-null  float64
#  7   end station id           30086 non-null  int64
#  8   end station name         30086 non-null  object
#  9   end station latitude     30086 non-null  float64
#  10  end station longitude    30086 non-null  float64
#  11  bikeid                   30086 non-null  int64
#  12  usertype                 30086 non-null  object
#  13  birth year               30086 non-null  int64
# ...

# %%
data_11=pd.read_csv('D:\GT-VIRT-DATA-PT-03-2022-U-LOL\CitiBike\Resources\JC-202011-citibike-tripdata.csv')

# %%
data_11.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           756  2020-11-01 00:11:32.6250  2020-11-01 00:24:09.5850
# 1           584  2020-11-01 00:14:20.4820  2020-11-01 00:24:04.7820
# 2           403  2020-11-01 00:22:55.8820  2020-11-01 00:29:39.0950
# 3           498  2020-11-01 00:41:37.4270  2020-11-01 00:49:55.7010
# 4           151  2020-11-01 00:53:21.2340  2020-11-01 00:55:52.8060
#
#    start station id start station name  start station latitude  \
# 0              3275     Columbus Drive               40.718355
# 1              3681           Grand St               40.715178
# 2              3203      Hamilton Park               40.727596
# 3              3268     Lafayette Park               40.713464
# 4              3185          City Hall               40.717732
#
#    start station longitude  end station id       end station name  \
# 0               -74.038914            3225  Baldwin at Montgomery
# ...

# %%
data_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21275 entries, 0 to 21274
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             21275 non-null  int64
#  1   starttime                21275 non-null  object
#  2   stoptime                 21275 non-null  object
#  3   start station id         21275 non-null  int64
#  4   start station name       21275 non-null  object
#  5   start station latitude   21275 non-null  float64
#  6   start station longitude  21275 non-null  float64
#  7   end station id           21275 non-null  int64
#  8   end station name         21275 non-null  object
#  9   end station latitude     21275 non-null  float64
#  10  end station longitude    21275 non-null  float64
#  11  bikeid                   21275 non-null  int64
#  12  usertype                 21275 non-null  object
#  13  birth year               21275 non-null  int64
# ...

# %%
data_12=pd.read_csv('D:\GT-VIRT-DATA-PT-03-2022-U-LOL\CitiBike\Resources\JC-202012-citibike-tripdata.csv')

# %%
data_12.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           146  2020-12-01 00:02:50.1450  2020-12-01 00:05:16.1940
# 1           572  2020-12-01 00:11:57.3910  2020-12-01 00:21:30.2510
# 2           387  2020-12-01 00:14:49.3610  2020-12-01 00:21:16.8730
# 3           188  2020-12-01 00:45:06.3680  2020-12-01 00:48:14.4280
# 4           594  2020-12-01 01:17:17.0110  2020-12-01 01:27:11.9400
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3640     Journal Square               40.733670
# 2              3640     Journal Square               40.733670
# 3              3186      Grove St PATH               40.719586
# 4              3212    Christ Hospital               40.734786
#
#    start station longitude  end station id end station name  \
# 0               -74.033759            3199     Newport Pkwy
# ...

# %%
data_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11694 entries, 0 to 11693
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             11694 non-null  int64
#  1   starttime                11694 non-null  object
#  2   stoptime                 11694 non-null  object
#  3   start station id         11694 non-null  int64
#  4   start station name       11694 non-null  object
#  5   start station latitude   11694 non-null  float64
#  6   start station longitude  11694 non-null  float64
#  7   end station id           11694 non-null  int64
#  8   end station name         11694 non-null  object
#  9   end station latitude     11694 non-null  float64
#  10  end station longitude    11694 non-null  float64
#  11  bikeid                   11694 non-null  int64
#  12  usertype                 11694 non-null  object
#  13  birth year               11694 non-null  int64
# ...

# %%
merge_data_78=pd.merge(data_07, data_08, how = 'outer')
merge_data_78
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1              1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2               786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3              1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4              2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
# ...             ...                       ...                       ...
# 81942           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 81943           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 81944           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 81945           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 81946           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
#        start station id          start station name  start station latitude  \
# ...

# %%
merge_data_789=pd.merge(merge_data_78,data_09, how='outer')

# %%
merge_data_789.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1          1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2           786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3          1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4          2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
#
#    start station id          start station name  start station latitude  \
# 0              3694              Jackson Square               40.711130
# 1              3791  Hoboken Ave at Monmouth St               40.735208
# 2              3792  Columbus Dr at Exchange Pl               40.716870
# 3              3677                Glenwood Ave               40.727551
# 4              3191                    Union St               40.718211
#
#    start station longitude  end station id       end station name  \
# ...

# %%
merge_data_78910=pd.merge(merge_data_789,data_10, how='outer')

# %%
merge_data_78911=pd.merge(merge_data_78910,data_11, how='outer')

# %%
merge_data_712=pd.merge(merge_data_78911,data_12, how='outer')

# %%
merge_data_712
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1               1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2                786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3               1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4               2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
# ...              ...                       ...                       ...
# 185379          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 185380          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 185381          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 185382           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 185383          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id          start station name  start station latitude  \
# ...

# %%
merge_data_712.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185384 entries, 0 to 185383
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             185384 non-null  int64
#  1   starttime                185384 non-null  object
#  2   stoptime                 185384 non-null  object
#  3   start station id         185384 non-null  int64
#  4   start station name       185384 non-null  object
#  5   start station latitude   185384 non-null  float64
#  6   start station longitude  185384 non-null  float64
#  7   end station id           185384 non-null  int64
#  8   end station name         185384 non-null  object
#  9   end station latitude     185384 non-null  float64
#  10  end station longitude    185384 non-null  float64
#  11  bikeid                   185384 non-null  int64
#  12  usertype                 185384 non-null  object
# ...

# %%
merge_data_7121=merge_data_712.loc[merge_data_712["tripduration"]>120]

# %%
merge_data_7121
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1               1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2                786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3               1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4               2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
# ...              ...                       ...                       ...
# 185379          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 185380          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 185381          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 185382           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 185383          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id          start station name  start station latitude  \
# ...

# %%
merge_data_final1 = merge_data_7121.reset_index(drop=True)

# %%
merge_data_final1
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1               1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2                786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3               1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4               2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
# ...              ...                       ...                       ...
# 182029          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 182030          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 182031          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 182032           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 182033          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id          start station name  start station latitude  \
# ...

# %%
merge_data_final2=merge_data_final1.loc[merge_data_final1["tripduration"]<1440]

# %%
merge_data_final2
# Out:
#         tripduration                 starttime                  stoptime  \
# 1               1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2                786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 5                750  2020-07-01 01:05:08.8790  2020-07-01 01:17:39.2000
# 6                529  2020-07-01 01:13:12.2900  2020-07-01 01:22:02.2810
# 7                824  2020-07-01 01:29:46.1440  2020-07-01 01:43:30.2360
# ...              ...                       ...                       ...
# 182025           626  2020-12-31 22:14:24.1850  2020-12-31 22:24:50.2050
# 182026           704  2020-12-31 22:37:08.3630  2020-12-31 22:48:52.5220
# 182027           653  2020-12-31 22:38:25.4680  2020-12-31 22:49:18.5150
# 182028           982  2020-12-31 22:59:05.5250  2020-12-31 23:15:28.3710
# 182032           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
#
#         start station id          start station name  start station latitude  \
# ...

# %%
merge_data_final = merge_data_final2.reset_index(drop=True)

# %%
merge_data_final
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 1                786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 2                750  2020-07-01 01:05:08.8790  2020-07-01 01:17:39.2000
# 3                529  2020-07-01 01:13:12.2900  2020-07-01 01:22:02.2810
# 4                824  2020-07-01 01:29:46.1440  2020-07-01 01:43:30.2360
# ...              ...                       ...                       ...
# 135339           626  2020-12-31 22:14:24.1850  2020-12-31 22:24:50.2050
# 135340           704  2020-12-31 22:37:08.3630  2020-12-31 22:48:52.5220
# 135341           653  2020-12-31 22:38:25.4680  2020-12-31 22:49:18.5150
# 135342           982  2020-12-31 22:59:05.5250  2020-12-31 23:15:28.3710
# 135343           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
#
#         start station id          start station name  start station latitude  \
# ...

# %%
merge_data_final.dropna()
merge_data_final[merge_data_final.gender!=0]
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 1                786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 4                824  2020-07-01 01:29:46.1440  2020-07-01 01:43:30.2360
# 6                569  2020-07-01 01:41:39.7920  2020-07-01 01:51:09.7270
# 7                535  2020-07-01 01:42:09.6900  2020-07-01 01:51:05.1650
# ...              ...                       ...                       ...
# 135334           301  2020-12-31 22:07:03.0280  2020-12-31 22:12:04.2870
# 135335           224  2020-12-31 22:09:56.0360  2020-12-31 22:13:40.5550
# 135336           591  2020-12-31 22:10:54.8540  2020-12-31 22:20:46.1760
# 135337           585  2020-12-31 22:11:08.4300  2020-12-31 22:20:53.8980
# 135341           653  2020-12-31 22:38:25.4680  2020-12-31 22:49:18.5150
#
#         start station id          start station name  start station latitude  \
# ...

# %%
merge_data_final=merge_data_final[merge_data_final.gender!=0]

# %%
merge_data_final=merge_data_final.replace({'gender': 1}, {'gender': 'Male'}, regex=True)

# %%
merge_data_final=merge_data_final.replace({'gender': 2}, {'gender': 'Female'}, regex=True)

# %%
merge_data_final
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 1                786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 4                824  2020-07-01 01:29:46.1440  2020-07-01 01:43:30.2360
# 6                569  2020-07-01 01:41:39.7920  2020-07-01 01:51:09.7270
# 7                535  2020-07-01 01:42:09.6900  2020-07-01 01:51:05.1650
# ...              ...                       ...                       ...
# 135334           301  2020-12-31 22:07:03.0280  2020-12-31 22:12:04.2870
# 135335           224  2020-12-31 22:09:56.0360  2020-12-31 22:13:40.5550
# 135336           591  2020-12-31 22:10:54.8540  2020-12-31 22:20:46.1760
# 135337           585  2020-12-31 22:11:08.4300  2020-12-31 22:20:53.8980
# 135341           653  2020-12-31 22:38:25.4680  2020-12-31 22:49:18.5150
#
#         start station id          start station name  start station latitude  \
# ...

# %%
merge_data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117231 entries, 0 to 135341
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             117231 non-null  int64
#  1   starttime                117231 non-null  object
#  2   stoptime                 117231 non-null  object
#  3   start station id         117231 non-null  int64
#  4   start station name       117231 non-null  object
#  5   start station latitude   117231 non-null  float64
#  6   start station longitude  117231 non-null  float64
#  7   end station id           117231 non-null  int64
#  8   end station name         117231 non-null  object
#  9   end station latitude     117231 non-null  float64
#  10  end station longitude    117231 non-null  float64
#  11  bikeid                   117231 non-null  int64
#  12  usertype                 117231 non-null  object
# ...

# %%
# Add ride id column to uniquely identify each ride
merge_data_final["bikeid"] = merge_data_final["start station id"].map(str) + "_" + merge_data_final["end station id"].map(str)
merge_data_final.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 1           786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 4           824  2020-07-01 01:29:46.1440  2020-07-01 01:43:30.2360
# 6           569  2020-07-01 01:41:39.7920  2020-07-01 01:51:09.7270
# 7           535  2020-07-01 01:42:09.6900  2020-07-01 01:51:05.1650
#
#    start station id          start station name  start station latitude  \
# 0              3791  Hoboken Ave at Monmouth St               40.735208
# 1              3792  Columbus Dr at Exchange Pl               40.716870
# 4              3186               Grove St PATH               40.719586
# 6              3639                  Harborside               40.719252
# 7              3639                  Harborside               40.719252
#
#    start station longitude  end station id       end station name  \
# ...

# %%
# Calculate age of riders
ages = []

for i in merge_data_final["birth year"]:
    age = 2022 - i
    ages.append(age)

# %%
merge_data_final['Age'] = ages
merge_data_final.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 1           786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 4           824  2020-07-01 01:29:46.1440  2020-07-01 01:43:30.2360
# 6           569  2020-07-01 01:41:39.7920  2020-07-01 01:51:09.7270
# 7           535  2020-07-01 01:42:09.6900  2020-07-01 01:51:05.1650
#
#    start station id          start station name  start station latitude  \
# 0              3791  Hoboken Ave at Monmouth St               40.735208
# 1              3792  Columbus Dr at Exchange Pl               40.716870
# 4              3186               Grove St PATH               40.719586
# 6              3639                  Harborside               40.719252
# 7              3639                  Harborside               40.719252
#
#    start station longitude  end station id       end station name  \
# ...

# %%
# Delete all rows where user age is over 70
merge_data_final3= merge_data_final.loc[merge_data_final["Age"] <= 70]

# %%
merge_data_final3
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 1                786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 4                824  2020-07-01 01:29:46.1440  2020-07-01 01:43:30.2360
# 6                569  2020-07-01 01:41:39.7920  2020-07-01 01:51:09.7270
# 7                535  2020-07-01 01:42:09.6900  2020-07-01 01:51:05.1650
# ...              ...                       ...                       ...
# 135334           301  2020-12-31 22:07:03.0280  2020-12-31 22:12:04.2870
# 135335           224  2020-12-31 22:09:56.0360  2020-12-31 22:13:40.5550
# 135336           591  2020-12-31 22:10:54.8540  2020-12-31 22:20:46.1760
# 135337           585  2020-12-31 22:11:08.4300  2020-12-31 22:20:53.8980
# 135341           653  2020-12-31 22:38:25.4680  2020-12-31 22:49:18.5150
#
#         start station id          start station name  start station latitude  \
# ...

# %%
merge_data_final4 = merge_data_final3.reset_index(drop=True)

# %%
merge_data_final4
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 1                786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 2                824  2020-07-01 01:29:46.1440  2020-07-01 01:43:30.2360
# 3                569  2020-07-01 01:41:39.7920  2020-07-01 01:51:09.7270
# 4                535  2020-07-01 01:42:09.6900  2020-07-01 01:51:05.1650
# ...              ...                       ...                       ...
# 116808           301  2020-12-31 22:07:03.0280  2020-12-31 22:12:04.2870
# 116809           224  2020-12-31 22:09:56.0360  2020-12-31 22:13:40.5550
# 116810           591  2020-12-31 22:10:54.8540  2020-12-31 22:20:46.1760
# 116811           585  2020-12-31 22:11:08.4300  2020-12-31 22:20:53.8980
# 116812           653  2020-12-31 22:38:25.4680  2020-12-31 22:49:18.5150
#
#         start station id          start station name  start station latitude  \
# ...

# %%
# Group ages in bins

# %%
bins = [0,17,30,40,50,60,70]
labels=['0-17', '18-29', '30-39','40-49', '50-59','60-70']

# %%
merge_data_final4['Age group']=pd.cut(merge_data_final4['Age'],bins,labels=labels)

# %%
del merge_data_final4['Age']

# %%
merge_data_final4
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 1                786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 2                824  2020-07-01 01:29:46.1440  2020-07-01 01:43:30.2360
# 3                569  2020-07-01 01:41:39.7920  2020-07-01 01:51:09.7270
# 4                535  2020-07-01 01:42:09.6900  2020-07-01 01:51:05.1650
# ...              ...                       ...                       ...
# 116808           301  2020-12-31 22:07:03.0280  2020-12-31 22:12:04.2870
# 116809           224  2020-12-31 22:09:56.0360  2020-12-31 22:13:40.5550
# 116810           591  2020-12-31 22:10:54.8540  2020-12-31 22:20:46.1760
# 116811           585  2020-12-31 22:11:08.4300  2020-12-31 22:20:53.8980
# 116812           653  2020-12-31 22:38:25.4680  2020-12-31 22:49:18.5150
#
#         start station id          start station name  start station latitude  \
# ...

# %%
# Python 3 program to calculate Distance Between Two Points on Earth
from math import sin, cos, sqrt, atan2, radians
# def distance(lat1, lat2, lon1, lon2):



# Convert degrees to radians
lat1 = [radians(lat) for lat in merge_data_final4["start station latitude"]]
lon1 = [radians(lon) for lon in merge_data_final4["start station longitude"]]
lat2 = [radians(lat) for lat in merge_data_final4["end station latitude"]]
lon2 = [radians(lon) for lon in merge_data_final4["end station longitude"]]


# Convert lists into series
lat1 = pd.Series(lat1)
lon1 = pd.Series(lon1)
lat2 = pd.Series(lat2)
lon2 = pd.Series(lon2)

#  Calculate difference between each set of latitude and longitude
dlat = lat2 - lat1
dlon = lon2 - lon1

# %%
# Approximate radius of Earth in km
R = 6373.0

# Empty list to store trip distances
distance = []

for i in range(0, len(lat1)):
    
    a = sin(dlat[i] / 2)**2 + cos(lat1[i]) * cos(lat2[i]) * sin(dlon[i] / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    # Get distance and convert km to miles
    miles = (R * c) * .6214
    
    # Append miles travel to 'distance' list
    distance.append(miles)

# %%
# Add trip distance as new column to data frame
merge_data_final4["tripdistance (mi)"] = distance
merge_data_final4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 1           786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 2           824  2020-07-01 01:29:46.1440  2020-07-01 01:43:30.2360
# 3           569  2020-07-01 01:41:39.7920  2020-07-01 01:51:09.7270
# 4           535  2020-07-01 01:42:09.6900  2020-07-01 01:51:05.1650
#
#    start station id          start station name  start station latitude  \
# 0              3791  Hoboken Ave at Monmouth St               40.735208
# 1              3792  Columbus Dr at Exchange Pl               40.716870
# 2              3186               Grove St PATH               40.719586
# 3              3639                  Harborside               40.719252
# 4              3639                  Harborside               40.719252
#
#    start station longitude  end station id       end station name  \
# ...

# %%
 merge_data_final4['tripdistance (mi)'] = merge_data_final4['tripdistance (mi)'].round(decimals = 2)

# %%
 merge_data_final4
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 1                786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 2                824  2020-07-01 01:29:46.1440  2020-07-01 01:43:30.2360
# 3                569  2020-07-01 01:41:39.7920  2020-07-01 01:51:09.7270
# 4                535  2020-07-01 01:42:09.6900  2020-07-01 01:51:05.1650
# ...              ...                       ...                       ...
# 116808           301  2020-12-31 22:07:03.0280  2020-12-31 22:12:04.2870
# 116809           224  2020-12-31 22:09:56.0360  2020-12-31 22:13:40.5550
# 116810           591  2020-12-31 22:10:54.8540  2020-12-31 22:20:46.1760
# 116811           585  2020-12-31 22:11:08.4300  2020-12-31 22:20:53.8980
# 116812           653  2020-12-31 22:38:25.4680  2020-12-31 22:49:18.5150
#
#         start station id          start station name  start station latitude  \
# ...

# %%
 merge_data_final4.to_csv("final_data.csv", encoding='utf-8', index=False)

# %% [markdown]
# ### End
